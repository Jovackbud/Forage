# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Excel file into a variable
transactions = pd.DataFrame(pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name=1))
new_customers_list = pd.DataFrame(pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name=2))
customer_demographic = pd.DataFrame(pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name=3))
customer_address = pd.DataFrame(pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name=4))
# Out:
# <ipython-input-4-6e689c35e69d>:3: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   new_customers_list = pd.DataFrame(pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name=2))
# <ipython-input-4-6e689c35e69d>:4: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   customer_demographic = pd.DataFrame(pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name=3))

# %%
customer_demographic.head(5)
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
sns.countplot(x = customer_demographic['wealth_segment'])
# mostly mass customer
# Out:
# <AxesSubplot:xlabel='wealth_segment', ylabel='count'>

# %%
plt.figure(figsize=(17,5))
sns.countplot(x = customer_demographic['job_industry_category'])
#mostly financial services, manufacturing and health
# Out:
# <AxesSubplot:xlabel='job_industry_category', ylabel='count'>

# %%
sns.countplot(x= customer_demographic['gender'])
#no difference between gender
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=customer_demographic, x = 'job_industry_category', hue='gender')
# Out:
# <AxesSubplot:xlabel='job_industry_category', ylabel='count'>

# %%
plt.figure(figsize=(17,5))
sns.barplot(data=customer_demographic, x='job_industry_category', y='past_3_years_bike_related_purchases', hue='owns_car')
# owning a car did not affect purchases just as industry doesn't affect purchases
# Out:
# <AxesSubplot:xlabel='job_industry_category', ylabel='past_3_years_bike_related_purchases'>

# %%
plt.figure(figsize=(17,5))
sns.barplot(data=customer_demographic, x='job_industry_category', y='past_3_years_bike_related_purchases')
# Out:
# <AxesSubplot:xlabel='job_industry_category', ylabel='past_3_years_bike_related_purchases'>

# %%
plt.figure(figsize=(17,5))
sns.boxplot(data=customer_demographic, x='job_industry_category', y='past_3_years_bike_related_purchases')
# Out:
# <AxesSubplot:xlabel='job_industry_category', ylabel='past_3_years_bike_related_purchases'>

# %%
plt.figure(figsize=(17,5))
sns.lineplot(data=customer_demographic, x='wealth_segment', y='past_3_years_bike_related_purchases')
# Out:
# <AxesSubplot:xlabel='wealth_segment', ylabel='past_3_years_bike_related_purchases'>

# %%
customer_address.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=customer_address, x='property_valuation', hue='state')
# most customers are overwhelmingly from NSW followed by VIC. The property valuation are also typically from 7-12
# Out:
# <AxesSubplot:xlabel='property_valuation', ylabel='count'>

# %%
transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date
# ...

# %%
sns.countplot(data=transactions, x='product_class', hue='product_line')
# most purchases were of medium product class and standard product line
# Out:
# <AxesSubplot:xlabel='product_class', ylabel='count'>

# %%
sns.countplot(data=transactions, x='product_size', hue='brand')
# mostly medium size products and doesnt vary much across products
# Out:
# <AxesSubplot:xlabel='product_size', ylabel='count'>

# %% [markdown]
# customer_d_data = customer_demographic[['past_3_years_bike_related_purchases', 'job_industry_category', 'wealth_segment']]
# customer_address_data = customer_address[['state', 'property_valuation']]
# transactions_data = transactions[['product_class', 'product_size']]

# %%
df = customer_demographic.join('customer_address', on='customer_id', how='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-dbc41b63e14d> in <module>
# ----> 1 df = customer_demographic.join('customer_address', on='customer_id', how='left')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9261         5  K1  A5   B1
#    9262         """
# -> 9263         return self._join_compat(
#    9264             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9265         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9304         else:
#    9305             if on is not None:
# -> 9306                 raise ValueError(
#    9307                     "Joining multiple DataFrames only supported for joining on index"
#    9308                 )
#
# ...

# %%
pd.concat([customer_demographic, , transactions], join=)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27999 entries, 0 to 19999
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          27999 non-null  int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   float64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X = df.drop(['past_3_years_bike_related_purchases'], axis=1)
y = df['past_3_years_bike_related_purchases']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
dtc = LogisticRegression()

# %%
dtc.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-162-afa9f1ef8a7b> in <module>
# ----> 1 dtc.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1340             _dtype = [np.float64, np.float32]
#    1341
# -> 1342         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1343                                    order="C",
#    1344                                    accept_large_sparse=solver != 'liblinear')
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ...
